# %%
# https://colab.research.google.com/github/bincooo/sd-webui-colab/blob/main/chillout_nebula_webui_colab.ipynb
import sys
import os
import base64

w = base64.b64decode(("d2VidQ==").encode('ascii')).decode('ascii')
sdw = base64.b64decode(("c3RhYmxlLWRpZmZ1c2lvbi13ZWJ1").encode('ascii')).decode('ascii')


# %cd /content

# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb
# !wget https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt install -qq libunwind8-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb

# !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !pip install -q xformers==0.0.16 triton==2.0.0 -U

# !git clone -b v2.1 https://github.com/camenduru/{sdw}i
# !git clone https://huggingface.co/embed/negative /content/{sdw}i/embeddings/negative
# !git clone https://huggingface.co/embed/lora /content/{sdw}i/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/{sdw}i/models/ESRGAN -o 4x-UltraSharp.pth
# !wget https://raw.githubusercontent.com/camenduru/{sdw}i-scripts/main/run_n_times.py -O /content/{sdw}i/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-{w}i /content/{sdw}i/extensions/deforum-for-automatic1111-{w}i
# !git clone https://github.com/camenduru/{sdw}i-images-browser /content/{sdw}i/extensions/{sdw}i-images-browser
# !git clone https://github.com/camenduru/{sdw}i-huggingface /content/{sdw}i/extensions/{sdw}i-huggingface
# !git clone https://github.com/camenduru/sd-civitai-browser /content/{sdw}i/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-{w}i-additional-networks /content/{sdw}i/extensions/sd-{w}i-additional-networks
# !git clone https://github.com/Mikubill/sd-{w}i-controlnet /content/{sdw}i/extensions/sd-{w}i-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/{sdw}i/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-{w}i-depth-lib /content/{sdw}i/extensions/sd-{w}i-depth-lib
# !git clone https://github.com/hnmr293/posex /content/{sdw}i/extensions/posex
# !git clone https://github.com/nonnonstop/sd-{w}i-3d-open-pose-editor /content/{sdw}i/extensions/sd-{w}i-3d-open-pose-editor
# !git clone https://github.com/camenduru/sd-{w}i-tunnels /content/{sdw}i/extensions/sd-{w}i-tunnels
# !git clone https://github.com/etherealxx/batchlinks-{w}i /content/{sdw}i/extensions/batchlinks-{w}i
# !git clone https://github.com/camenduru/{sdw}i-catppuccin /content/{sdw}i/extensions/{sdw}i-catppuccin
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-{w}i-locon /content/{sdw}i/extensions/a1111-sd-{w}i-locon
# !git clone https://github.com/AUTOMATIC1111/{sdw}i-rembg /content/{sdw}i/extensions/{sdw}i-rembg
# !git clone https://github.com/ashen-sensored/{sdw}i-two-shot /content/{sdw}i/extensions/{sdw}i-two-shot
# !git clone https://github.com/camenduru/sd_{w}i_stealth_pnginfo /content/{sdw}i/extensions/sd_{w}i_stealth_pnginfo
# !git clone https://github.com/thomasasfk/sd-{w}i-aspect-ratio-helper /content/{sdw}i/extensions/sd-{w}i-aspect-ratio-helper
# !git clone https://github.com/mcmonkeyprojects/sd-dynamic-thresholding.git /content/{sdw}i/extensions/sd-dynamic-thresholding

# %cd /content/{sdw}i
# !git reset --hard
# !git -C /content/{sdw}i/repositories/stable-diffusion-stability-ai reset --hard

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11e_sd15_ip2p_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11e_sd15_shuffle_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_canny_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11f1p_sd15_depth_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_inpaint_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_lineart_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_mlsd_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_normalbae_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_openpose_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_scribble_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_seg_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_softedge_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11f1e_sd15_tile_fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11e_sd15_ip2p_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11e_sd15_shuffle_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_canny_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11f1p_sd15_depth_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_inpaint_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_lineart_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_mlsd_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_normalbae_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_openpose_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_scribble_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_seg_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_seg_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15_softedge_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11p_sd15s2_lineart_anime_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o control_v11f1e_sd15_tile_fp16.yaml
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_style_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_color_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_canny_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_canny_sd15v2.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_canny_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_depth_sd15v2.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_depth_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_sketch_sd15v2.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_sketch_sd15v2.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/t2iadapter_zoedepth_sd15v1.pth -d /content/{sdw}i/extensions/sd-{w}i-controlnet/models -o t2iadapter_zoedepth_sd15v1.pth

#https://civitai.com/models/47274/xxmix9realistic
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/67239 -d /content/{sdw}i/models/Stable-diffusion -o xxmix9realistic.safetensors
#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/{sdw}i/models/Stable-diffusion -o chilloutnebula_20.vae.pt
#https://civitai.com/models/58390/detail-tweaker-lora-lora 细节优化
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/62833 -d /content/{sdw}i/models/Lora -o detail-tweaker-lora.safetensors
#https://civitai.com/models/65740/supergirl-cosplay-outfit 女超人
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/70390 -d /content/{sdw}i/models/Lora -o supergirl-cosplay-outfit.safetensors
#https://civitai.com/models/65314/hanfu-ming 汉服
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/69953 -d /content/{sdw}i/models/Lora -o hanfu-ming.safetensors

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/'{sdw}'i/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/{sdw}i/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/{sdw}i/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --gradio-queue --multiple --api
